# %% [raw]
# !pip install pandas

# %%
# txt, csv, json files => Load and read the content

# DataFrame => Tabular View

[Name | Place | Gender  | Age  | MOB]
['Tom', 'India', 'M', 25, 'July']

# %%
data = {
    "name" : ['Vinay', 'Kushal', 'Aman', 'Saif'],
    'age': [22, 25, 24, 28], 
    'occupation': ['engineer', 'doctor', 'data analyst', 'teacher']
}

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#      name  age    occupation
# 0   Vinay   22      engineer
# 1  Kushal   25        doctor
# 2    Aman   24  data analyst
# 3    Saif   28       teacher

# %%
file_path = "3_Introduction_to_Pandas/global_sales_data/market_fact.csv"
df = pd.read_csv(file_path)
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.3+ KB

# %%
df.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
df.shape
# Out:
# (8399, 10)

# %%
df['Ord_id']
# Out:
# 0       Ord_5446
# 1       Ord_5406
# 2       Ord_5446
# 3       Ord_5456
# 4       Ord_5485
#           ...
# 8394    Ord_5353
# 8395    Ord_5411
# 8396    Ord_5388
# 8397    Ord_5348
# 8398    Ord_5459
# Name: Ord_id, Length: 8399, dtype: object

# %%
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
df.tail()
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8394              28  374.63           7.69                 0.59
# 8395              20  -74.03           6.92                 0.37
# 8396              39  -70.85           5.35                 0.40
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Ord_id'])
# Out:
# pandas.core.series.Series

# %%
df[2:10] # S:E:I
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9  Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 2              26  1148.90           2.50                 0.59
# 3              43   729.34          14.30                 0.37
# 4              35  1219.87          26.30                 0.38
# 5              23   -47.64           6.15                 0.37
# 6               5     1.32           0.50                 0.36
# ...

# %%
df[2:10:2] #S:E:I
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.76      0.01               5
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.00      0.01              33
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 2  1148.90           2.50                 0.59
# 4  1219.87          26.30                 0.38
# 6     1.32           0.50                 0.36
# 8    45.84           0.71                 0.52

# %%
df[["Cust_id", "Sales", "Profit"]]
# Out:
#         Cust_id      Sales   Profit
# 0     Cust_1818   136.8100   -30.51
# 1     Cust_1818    42.2700     4.56
# 2     Cust_1818  4701.6900  1148.90
# 3     Cust_1818  2337.8900   729.34
# 4     Cust_1818  4233.1500  1219.87
# ...         ...        ...      ...
# 8394  Cust_1798  2841.4395   374.63
# 8395  Cust_1798   127.1600   -74.03
# 8396  Cust_1798   243.0500   -70.85
# 8397  Cust_1798  3872.8700   565.34
# 8398  Cust_1798   603.6900   131.39
#
# [8399 rows x 3 columns]

# %%
df[["Cust_id", "Sales", "Profit"]][2:10]
# Out:
#      Cust_id      Sales   Profit
# 2  Cust_1818  4701.6900  1148.90
# 3  Cust_1818  2337.8900   729.34
# 4  Cust_1818  4233.1500  1219.87
# 5  Cust_1818   164.0200   -47.64
# 6    Cust_26    14.7600     1.32
# 7  Cust_1641  3410.1575  1137.91
# 8  Cust_1641   162.0000    45.84
# 9  Cust_1641    57.2200   -27.72

# %%
df_1 = df.set_index("Ord_id")
df_1
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08              35
# ...           ...       ...        ...        ...       ...             ...
# Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
# Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10              20
# Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02              39
# Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03              23
# Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00              47
#
# ...

# %%
df_1.loc['Ord_5446']
# Out:
#           Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5446   -30.51           3.60                 0.56
# Ord_5446  1148.90           2.50                 0.59
# Ord_5446   -47.64           6.15                 0.37

# %%
df_1.iloc[0]
# Out:
# Prod_id                  Prod_16
# Ship_id                 SHP_7609
# Cust_id                Cust_1818
# Sales                     136.81
# Discount                    0.01
# Order_Quantity                23
# Profit                    -30.51
# Shipping_Cost                3.6
# Product_Base_Margin         0.56
# Name: Ord_5446, dtype: object

# %%
df_1.iloc[0:1] # integer/position based
# Out:
#           Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01              23
#
#           Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5446  -30.51            3.6                 0.56

# %%
df_1.loc[['Ord_5446','Ord_5456']] # label based
# Out:
#           Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5446   -30.51           3.60                 0.56
# Ord_5446  1148.90           2.50                 0.59
# Ord_5446   -47.64           6.15                 0.37
# Ord_5456   729.34          14.30                 0.37

# %%
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
# Get me the orders which made Sales > 3000
df.Sales>3000
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 8394    False
# 8395    False
# 8396    False
# 8397     True
# 8398    False
# Name: Sales, Length: 8399, dtype: bool

# %%
df[df.Sales>3000]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 13    Ord_2207  Prod_11  SHP_3093   Cust_839   3364.2480      0.10
# ...        ...      ...       ...        ...         ...       ...
# 8366  Ord_3593   Prod_3  SHP_4974  Cust_1274  12073.0600      0.03
# 8367  Ord_3593  Prod_15  SHP_4975  Cust_1274   6685.0500      0.09
# 8371  Ord_2624   Prod_4  SHP_3591  Cust_1006   4924.1350      0.07
# 8383  Ord_2722   Prod_1  SHP_3731  Cust_1006   3508.3300      0.04
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798   3872.8700      0.03
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 2                 26  1148.90           2.50                 0.59
# ...

# %%
# Get me the orders which made Sales greater than 2000 and less than 3000
df[(df.Sales>2000) & (df.Sales<3000)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 81    Ord_5205   Prod_4  SHP_7274  Cust_1749  2546.5235      0.09
# 98    Ord_5481  Prod_15  SHP_7659  Cust_1820  2700.7800      0.06
# 109    Ord_139  Prod_17   SHP_186    Cust_45  2671.2100      0.06
# 110    Ord_239   Prod_4   SHP_332    Cust_45  2157.3085      0.00
# ...        ...      ...       ...        ...        ...       ...
# 8351  Ord_3584  Prod_15  SHP_4961  Cust_1266  2502.6700      0.10
# 8354  Ord_3592   Prod_4  SHP_4973  Cust_1266  2614.3705      0.07
# 8360  Ord_3639  Prod_10  SHP_5038  Cust_1266  2173.2600      0.00
# 8381  Ord_2696   Prod_4  SHP_3691  Cust_1006  2836.0505      0.01
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 3                 43  729.34          14.30                 0.37
# ...

# %%
# Get me all orders with Sales between 2000 and 3000 or Profit greater than 100
df[((df.Sales>2000) & (df.Sales<3000)) | (df.Profit>100)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01
# ...        ...      ...       ...        ...        ...       ...
# 8381  Ord_2696   Prod_4  SHP_3691  Cust_1006  2836.0505      0.01
# 8385  Ord_1833   Prod_3  SHP_2527   Cust_637   611.1600      0.04
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 2                 26  1148.90           2.50                 0.59
# ...

# %%
customers_in_bangalore = ['Cust_1798', 'Cust_1519', 'Cust_637', 'Cust_851']
df[df.Cust_id.isin(customers_in_bangalore)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8385  Ord_1833   Prod_3  SHP_2527   Cust_637   611.1600      0.04
# 8386  Ord_2324   Prod_7  SHP_3189   Cust_851   121.8700      0.07
# 8387  Ord_2220   Prod_3  SHP_3019   Cust_851    41.0600      0.04
# 8388  Ord_4424   Prod_1  SHP_6165  Cust_1519   994.0400      0.03
# 8389  Ord_4444  Prod_13  SHP_6192  Cust_1519   159.4100      0.00
# 8390  Ord_5435  Prod_16  SHP_7594  Cust_1798   316.9900      0.04
# 8391  Ord_5435   Prod_4  SHP_7594  Cust_1798  1991.8985      0.07
# 8392  Ord_5384   Prod_9  SHP_7519  Cust_1798   181.5000      0.08
# 8393  Ord_5348   Prod_8  SHP_7470  Cust_1798   356.7200      0.07
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# ...
